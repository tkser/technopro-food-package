# %%
import sys
sys.path.append('../src')

from models.RegNetY128Model.train import train as train_RegNetY128Model

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_RegNetY128Model(
  num_epochs=5,
  learning_rate=1e-05,
  batch_size=2,
  flozen=True,
  seed=361
)
# Out:
# [DEBUG] 2023-09-28 21:37:37 - Using device: cuda(NVIDIA GeForce RTX 3080)
# [DEBUG] 2023-09-28 21:37:37 - Starting training on cuda at 2023-09-28 21:37:37
# [DEBUG] 2023-09-28 21:37:37 - Model: RegNet
# [DEBUG] 2023-09-28 21:37:37 - Model parameters:
# [DEBUG] 2023-09-28 21:37:37 - stem.0.weight: torch.Size([32, 3, 3, 3])
# [DEBUG] 2023-09-28 21:37:37 - stem.1.weight: torch.Size([32])
# [DEBUG] 2023-09-28 21:37:37 - stem.1.bias: torch.Size([32])
# [DEBUG] 2023-09-28 21:37:37 - trunk_output.block1.block1-0.proj.0.weight: torch.Size([528, 32, 1, 1])
# [DEBUG] 2023-09-28 21:37:37 - trunk_output.block1.block1-0.proj.1.weight: torch.Size([528])
# [DEBUG] 2023-09-28 21:37:37 - trunk_output.block1.block1-0.proj.1.bias: torch.Size([528])
# [DEBUG] 2023-09-28 21:37:37 - trunk_output.block1.block1-0.f.a.0.weight: torch.Size([528, 32, 1, 1])
# [DEBUG] 2023-09-28 21:37:37 - trunk_output.block1.block1-0.f.a.1.weight: torch.Size([528])
# ...

# %%
plot_history(loss_history, "RegNetY128Model Loss")

# %%
plot_history(auc_history, "RegNetY128Model AUC")
