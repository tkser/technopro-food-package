# %%
import sys
sys.path.append('../src')

from models.ViTH14Model.train import train as train_ViTH14Model

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_ViTH14Model(
    num_epochs=5,
    learning_rate=1e-05,
    batch_size=2,
    flozen=True,
    seed=1187
)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_h_14_swag-80465313.pth" to C:\Users\negi/.cache\torch\hub\checkpoints\vit_h_14_swag-80465313.pth
# 100%|██████████| 2.36G/2.36G [03:39<00:00, 11.5MB/s]
# [DEBUG] 2023-09-14 23:41:10 - Using device: cuda(NVIDIA GeForce RTX 3080)
# [DEBUG] 2023-09-14 23:41:10 - Starting training on cuda at 2023-09-14 23:41:10
# [DEBUG] 2023-09-14 23:41:10 - Model parameters:
# [DEBUG] 2023-09-14 23:41:10 - class_token: torch.Size([1, 1, 1280])
# [DEBUG] 2023-09-14 23:41:10 - conv_proj.weight: torch.Size([1280, 3, 14, 14])
# [DEBUG] 2023-09-14 23:41:10 - conv_proj.bias: torch.Size([1280])
# [DEBUG] 2023-09-14 23:41:10 - encoder.pos_embedding: torch.Size([1, 1370, 1280])
# [DEBUG] 2023-09-14 23:41:10 - encoder.layers.encoder_layer_0.ln_1.weight: torch.Size([1280])
# [DEBUG] 2023-09-14 23:41:10 - encoder.layers.encoder_layer_0.ln_1.bias: torch.Size([1280])
# ...

# %%
plot_history(loss_history, "ViTH14Model Loss")

# %%
plot_history(auc_history, "ViTH14Model AUC")
