# %%
import sys
sys.path.append('../src')

from models.EfficientNetV2Model.train import train as train_EfficientNetV2Model

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_EfficientNetV2Model(
    num_epochs=20,
    learning_rate=1e-5,
    flozen=True,
    seed=0
)
# Out:
# [DEBUG] 2023-09-28 01:34:47 - Using device: cuda(NVIDIA GeForce RTX 3080)
# [DEBUG] 2023-09-28 01:34:47 - Starting training on cuda at 2023-09-28 01:34:47
# [DEBUG] 2023-09-28 01:34:47 - Model: EfficientNet
# [DEBUG] 2023-09-28 01:34:47 - Model parameters:
# [DEBUG] 2023-09-28 01:34:47 - features.0.0.weight: torch.Size([32, 3, 3, 3])
# [DEBUG] 2023-09-28 01:34:47 - features.0.1.weight: torch.Size([32])
# [DEBUG] 2023-09-28 01:34:47 - features.0.1.bias: torch.Size([32])
# [DEBUG] 2023-09-28 01:34:47 - features.1.0.block.0.0.weight: torch.Size([32, 32, 3, 3])
# [DEBUG] 2023-09-28 01:34:47 - features.1.0.block.0.1.weight: torch.Size([32])
# [DEBUG] 2023-09-28 01:34:47 - features.1.0.block.0.1.bias: torch.Size([32])
# [DEBUG] 2023-09-28 01:34:47 - features.1.1.block.0.0.weight: torch.Size([32, 32, 3, 3])
# [DEBUG] 2023-09-28 01:34:47 - features.1.1.block.0.1.weight: torch.Size([32])
# [DEBUG] 2023-09-28 01:34:47 - features.1.1.block.0.1.bias: torch.Size([32])
# ...

# %%
plot_history(loss_history, "EfficientNetV2Model Loss History")

# %%
plot_history(auc_history, "EfficientNetV2Model AUC History")
