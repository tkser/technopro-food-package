# %%
import sys
sys.path.append('../src')

from models.ResNet152Model.train import train as train_ResNet152Model

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_ResNet152Model(
    num_epochs=50,
    learning_rate=1e-05
)
# Out:
# /home/education/technopro-food-package/.venv/lib/python3.11/site-packages/albumentations/augmentations/transforms.py:311: FutureWarning: JpegCompression has been deprecated. Please use ImageCompression
#   warnings.warn(
# /home/education/technopro-food-package/.venv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/education/technopro-food-package/.venv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# [DEBUG] 2023-08-31 15:10:13 - Starting training on cuda at 2023-09-01 00:10:13
# [DEBUG] 2023-08-31 15:10:13 - Model parameters:
# ...

# %%
plot_history(loss_history, "loss")

# %%
plot_history(auc_history, "auc")
