# %%
import sys
sys.path.append('../src')

from models.EfficientNetModel.train import train as train_EfficientNetModel

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_EfficientNetModel(
    num_epochs=20,
    learning_rate=1e-05,
    batch_size=16,
    flozen=True,
    model_type='b3',
)
# Out:
# [DEBUG] 2023-09-15 18:12:21 - Using device: cuda(NVIDIA GeForce RTX 3080)
# [DEBUG] 2023-09-15 18:12:21 - Starting training on cuda at 2023-09-15 18:12:21
# [DEBUG] 2023-09-15 18:12:21 - Model parameters:
# [DEBUG] 2023-09-15 18:12:21 - features.0.0.weight: torch.Size([40, 3, 3, 3])
# [DEBUG] 2023-09-15 18:12:21 - features.0.1.weight: torch.Size([40])
# [DEBUG] 2023-09-15 18:12:21 - features.0.1.bias: torch.Size([40])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.0.0.weight: torch.Size([40, 1, 3, 3])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.0.1.weight: torch.Size([40])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.0.1.bias: torch.Size([40])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.1.fc1.weight: torch.Size([10, 40, 1, 1])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.1.fc1.bias: torch.Size([10])
# [DEBUG] 2023-09-15 18:12:21 - features.1.0.block.1.fc2.weight: torch.Size([40, 10, 1, 1])
# ...

# %%
plot_history(loss_history, "EfficientNetModel B3 Loss")

# %%
plot_history(auc_history, "EfficientNetModel B3 AUC")
