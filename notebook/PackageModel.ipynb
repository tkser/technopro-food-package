# %%
import sys
sys.path.append('../src')

from models.PackageModel.train import train as train_PackageModel

from utils.show_graph import plot_history

# %%
package_model_path, loss_history, auc_history = train_PackageModel(
    num_epochs=50,
    learning_rate=0.0001
)
# Out:
# /home/education/technopro-food-package/.venv/lib/python3.11/site-packages/albumentations/augmentations/transforms.py:311: FutureWarning: JpegCompression has been deprecated. Please use ImageCompression
#   warnings.warn(
# [DEBUG] 2023-08-31 14:48:07 - Starting training on cuda at 2023-08-31 23:48:07
# [DEBUG] 2023-08-31 14:48:07 - Model parameters:
# [DEBUG] 2023-08-31 14:48:07 - layer1.0.weight: torch.Size([16, 3, 3, 3])
# [DEBUG] 2023-08-31 14:48:07 - layer1.0.bias: torch.Size([16])
# [DEBUG] 2023-08-31 14:48:07 - layer1.1.weight: torch.Size([16])
# [DEBUG] 2023-08-31 14:48:07 - layer1.1.bias: torch.Size([16])
# [DEBUG] 2023-08-31 14:48:07 - layer2.0.weight: torch.Size([32, 16, 3, 3])
# [DEBUG] 2023-08-31 14:48:07 - layer2.0.bias: torch.Size([32])
# [DEBUG] 2023-08-31 14:48:07 - layer2.1.weight: torch.Size([32])
# [DEBUG] 2023-08-31 14:48:07 - layer2.1.bias: torch.Size([32])
# [DEBUG] 2023-08-31 14:48:07 - fc1.weight: torch.Size([32, 32768])
# ...

# %%
plot_history(loss_history, "loss")

# %%
plot_history(auc_history, "auc")
